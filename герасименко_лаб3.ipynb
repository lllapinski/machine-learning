# %% [markdown]
# # Лабораторна робота 3
# **Тема:** Лінійна регресія
#
# **Автор:** Herasymenko  •  **Варіант:** 1  •  **Дата:** 2025-10-28

# %%
# === Імпорт бібліотек ===
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error

pd.set_option('display.max_columns', 50)
print('✅ Імпорт виконано')
# Out:
# ✅ Імпорт виконано

# %% [markdown]
# ##  Завдання 1. Diabetes Dataset

# %% [markdown]
# ### 1. Завантажити Diabetes Dataset та вивести перших 5 рядків

# %%
# Умова: Завантажити датасет і показати перші 5 рядків
diabetes = datasets.load_diabetes()
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %% [markdown]
# Дані успішно завантажено з вбудованого набору sklearn.datasets.load_diabetes().
# Отримано таблицю, яка містить 10 числових ознак (age, sex, bmi, bp, s1–s6) та цільову змінну target, що відображає прогрес діабету через рік.
# У перших п’яти рядках видно, що всі значення — нормалізовані дійсні числа (масштабовані в діапазоні приблизно від -0.1 до 0.1), тобто датасет уже підготовлений для подальшого аналізу й навчання моделей.

# %% [markdown]
# ---
# ##  Завдання 2. California Housing Dataset

# %% [markdown]
# ### 1. Завантажити датасет і вивести перших 5 рядків

# %%
# Умова: Завантажити California Housing (вбудований у sklearn)
from sklearn.datasets import fetch_california_housing
cal = fetch_california_housing(as_frame=True)
df2 = cal.frame.copy()
df2.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %% [markdown]
# Датасет California Housing успішно завантажено з бібліотеки sklearn.datasets.
# Таблиця містить 8 числових ознак (наприклад: MedInc, HouseAge, AveRooms, AveBedrms, Population, AveOccup, Latitude, Longitude) та цільову змінну MedHouseVal, що відображає середню вартість житла в регіоні.
# Перші 5 рядків показують, що всі значення є числовими й готовими для аналізу — жодних пропусків або аномалій на цьому етапі не виявлено.
# Отже, датасет придатний для подальшої обробки, масштабування та побудови моделей регресії.
